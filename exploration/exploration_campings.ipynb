# %%
import polars as pl
import plotly.express as px

df = pl.read_csv("../data/raw/793866443_hotelleries-de-plein-air-camping-en-loire-atlantique.csv", separator=";")

df = df.with_columns([
    pl.col("Latitude").cast(pl.Float64).alias("lat"),
    pl.col("Longitude").cast(pl.Float64).alias("lon")
]).drop_nulls(["Latitude", "Longitude"])

# %%
pdf = df.to_pandas()

print(pdf.head())

fig = px.scatter_mapbox(
    pdf,
    lat="lat",
    lon="lon",
    color="Catégorie de l'offre",
    hover_name="Nom de l'offre touristique",
    zoom=6,
    height=700
)
# Out:
#           Nom de l'offre touristique           SyndicObjectID  \
# 0            Camping de la Morinière         HPAEPSPMORINIERE
# 1                 Camping La Chênaie              HPAECHENAIE
# 2             Camping - Les Ollivaud          HPAELESOLLIVAUD
# 3                Camping Les Bleuets             HPAEEBLEUETS
# 4  Siblu Village Le Bois de Bayadène  HPAHPAELEBOISDEBAYADENE
#
#     Type de l'offre Catégorie de l'offre Adresse1 Adresse partie 1 suite  \
# 0  Camp de tourisme             1 étoile     None                   None
# 1  Camp de tourisme            4 étoiles     None                   None
# 2  Camp de tourisme           Non Classé     None                   None
# 3  Camp de tourisme            2 étoiles     None                   None
# 4  Camp de tourisme            4 étoiles     None                   None
#
#          Adresse partie 2      Adresse partie 3  Code postal  \
# 0  17 rue de la Morinière                  None        44710
# 1     36 rue du Patisseau                  None        44210
# 2       La Ville Ollivaud                  D127        44500
# 3  Lieu-dit "Les Bleuets"  Sainte Marie sur Mer        44210
# 4       Route de Kerdrien                  None        44420
#
#     Nom de la commune  ...  \
# 0     PORT-SAINT-PERE  ...
# 1              PORNIC  ...
# 2  LA BAULE-ESCOUBLAC  ...
# 3              PORNIC  ...
# 4      PIRIAC-SUR-MER  ...
#
#    Période/horaires par jour/précisions ouverture/précision fermeture  \
# 0  01/06/2025||30/09/2025||||||||||||||||||||||||...
# 1  05/04/2025||13/09/2025||||||||||||||||||||||||...
# 2                                               None
# 3  01/04/2025||30/09/2025||||||||||||||||||||||||...
# 4  05/04/2025||01/11/2025||||||||||||||||||||||||...
#
#    Nom du contact/Tel contact/mail contact  \
# 0                                     None
# 1                                     None
# 2                                     None
# 3                                     None
# 4                                     None
#
#    Nom centrale de réservation en ligne Moyen(s) de réservation en ligne  \
# 0                                  None                             None
# 1                                  None                             None
# 2                                  None                             None
# 3                                  None                             None
# 4                                  None                             None
#
#                                        Tarifs  \
# 0                                        None
# 1  Taxe de séjour / nuit / pers||0,66||0,66||
# 2                                        None
# 3                                        None
# 4                                        None
#
#                           Modes de paiement acceptés        localisation  \
# 0          Cartes bancaires,Chèques Vacances,Espèces  47.13424, -1.74429
# 1  Cartes bancaires,Chèques bancaires et postaux,...  47.11881, -2.06979
# 2  Chèques bancaires et postaux,Chèques Vacances,...   47.30081, -2.3315
# 3  Cartes bancaires,Chèques bancaires et postaux,...   47.14034, -2.1306
# 4  Cartes bancaires,Chèques bancaires et postaux,...   47.3859, -2.51036
#
#         departement       lat      lon
# 0  Loire-Atlantique  47.13424 -1.74429
# 1  Loire-Atlantique  47.11881 -2.06979
# 2  Loire-Atlantique  47.30081 -2.33150
# 3  Loire-Atlantique  47.14034 -2.13060
# 4  Loire-Atlantique  47.38590 -2.51036
#
# [5 rows x 57 columns]
# C:\Users\cyber\AppData\Local\Temp\ipykernel_28580\2027122360.py:5: DeprecationWarning:
#
# *scatter_mapbox* is deprecated! Use *scatter_map* instead. Learn more at: https://plotly.com/python/mapbox-to-maplibre/

# %%
fig.update_layout(mapbox_style="open-street-map")
fig.show()
